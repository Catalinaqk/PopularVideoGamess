# %%
import pandas as pd
import seaborn as sns
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df = pd.read_csv('C:\\Users\\Asus\\Downloads\\Chemicals in Makeup.csv')
df
# Out:
#         CDPHId                                        ProductName    CSFId  \
# 0            2   ULTRA COLOR RICH EXTRA PLUMP LIPSTICK-ALL SHADES      NaN
# 1            3                         Glover's Medicated Shampoo      NaN
# 2            3                         Glover's Medicated Shampoo      NaN
# 3            4           PRECISION GLIMMER EYE LINER-ALL SHADES �      NaN
# 4            5        AVON BRILLIANT SHINE LIP GLOSS-ALL SHADES �      NaN
# ...        ...                                                ...      ...
# 114630   41523               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65001.0
# 114631   41523               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65002.0
# 114632   41523               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65003.0
# 114633   41523               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65004.0
# 114634   41524  OLD SPICE GENTLEMENS BLEND ALOE AND WILD SAGE ...      NaN
#
# ...

# %% [markdown]
# # Cautare dupa brand

# %%
brand_name_to_search = 'Avon'
result = df.loc[df['BrandName'] == brand_name_to_search]

result
# Out:
#        CDPHId                                        ProductName  CSFId  CSF  \
# 63427   22744           ULTRA GLAZEWEAR LIP GLOSS (ALL SHADES) �    NaN  NaN
# 63428   22745         KOHL EYE LINER WITH SMUDGER (ALL SHADES) �    NaN  NaN
# 63429   22746             TRUE COLOR EYESHADOW QUAD (ALL SHADES)    NaN  NaN
# 63430   22747              TRUE COLOR EYESHADOW DUO (ALL SHADES)    NaN  NaN
# 63431   22748         TRUE COLOR EYESHADOW SINGLE (ALL SHADES) �    NaN  NaN
# ...       ...                                                ...    ...  ...
# 71734   26137  NAILWEAR PRO PLUS ELECTRIC NAIL ENAMEL (ALL SH...    NaN  NaN
# 74939   26951                FLAVOR SAVERS LIP BALM (ALL SHADES)    NaN  NaN
# 75474   27099       Big & False Lash Volume Mascara (all shades)    NaN  NaN
# 78005   28072  ATTRACTION FOR HER SHOWER GEL & FOR HIM HAIR &...    NaN  NaN
# 78006   28072  ATTRACTION FOR HER SHOWER GEL & FOR HIM HAIR &...    NaN  NaN
#
# ...

# %% [markdown]
# Afisare toate brandurile

# %%
unique_brands = df['BrandName'].unique()
unique_brands
# Out:
# array(['AVON', "Glover's", 'OPI', ..., 'sulwhasoo ', 'HAIR FOOD',
#        'YANBAL'], shape=(2714,), dtype=object)
